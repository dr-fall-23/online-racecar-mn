# %%
# Import functions 
import sys
sys.path.insert(0, '..')
from racecar_utils import *
# Out:
# ROS node started successfully

# %% [markdown]
# # Line Following
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Today, we will create an algorithm for the racecar to detect and follow a colored line. We will have several different tape colors for the car to select from. Each path will lead us on a different path adventure!
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Depending on the color, the racecar may take a shorter or longer path to its final destination.
#     </p>

# %% [markdown]
# ## Step 1: Fix the Camera Offset
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     The camera is slightly shifted horizontally (x-axis).
#     <br> Update <code>SCREEN_CENTER</code> to re-set the center pixel location of your output image.
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     The function below draws a circle at <code>SCREEN_CENTER</code>.
#     <br> How to find the correct value:
#     <ol style='font-size:1.75rem;line-height:1.5'>
#         <li>Place an object directly in front of your camera at where you think center is.</li>
#         <li>Run the two cell blocks below to test your <code>SCREEN_CENTER</code> value. </li>
#         <li>Your drawn circle should be matched to the center of the object in the outputted image. </li>
#     </ol>
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Getting the correct <code>SCREEN_CENTER</code> value here will help you later in the the <code>get_angle</code> function.
#     </p>

# %%
SCREEN_CENTER = 325.0     # pixel x-axis, camera is right-shifted

# %%
# mark location of SCREEN_CENTER (x-axis)
def identify_center(color_img):
    if SCREEN_CENTER < 0 or SCREEN_CENTER > color_img.shape[1]:
        print('SCREEN_CENTER out of bounds! Your image is: {}'.format(color_img.shape[:2]))
    cv2.circle(color_img, (int(SCREEN_CENTER), color_img.shape[0]//2), 5, (0,255,0), 3)
    return color_img

# display image
show_video(identify_center)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-60451d5f07f4> in <module>
#       7
#       8 # display image
# ----> 9 show_video(identify_center)
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in show_video(func, time_limit, use_both_frames, show_video)
#     174         withRealSenseImages(display_both_frames, {'width': 640, 'height': 480, 'depth': use_both_frames}, time_limit)
#     175     else:
# --> 176         withRealSenseImages(display_frame, {'width': 640, 'height': 480, 'depth': use_both_frames}, time_limit)
#     177
#     178 def show_videox(func, time_limit = 10, use_both_frames = False, show_video = True):
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in withRealSenseImages(frameProcessor, options, limit)
#     138                                        np.asanyarray(depth_frame.get_data()))
#     139                 else:
# --> 140                     frameProcessor(np.asanyarray(frames.get_color_frame().get_data()))
#     141             elif depth:
#     142                 frameProcessor(np.asanyarray(frames.get_depth_frame().get_data()))
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in display_frame(color_image)
#     158             img = IPython.display.Image(data=f.getvalue())
#     159             display.update(img)
# --> 160             time.sleep(0.2)
#     161
#     162     def display_both_frames(color_image, depth_image):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 2: Crop Image
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     It is intuitive for us humans to trace the closest part of the line (the part under our feet) as we walk. However, the car sees a long line ahead of itself and doesn't know which part of the line to follow. We want to limit what the car sees/follows by limiting its field of view.
#       </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Modify <code>TOPLEFT_COORD</code> and <code>BOTTOMRIGHT_COORD</code> to crop the image below. The function draws a black rectangle over the top half of the image, showing only the part of the line that is closest to the car.
#     </p>

# %%
TOPLEFT_COORD = (0, 350)
BOTTOMRIGHT_COORD = (639, 0)

# %%
#draws rectangle over frame to crop
def crop(img):
    cv2.rectangle(img, TOPLEFT_COORD, BOTTOMRIGHT_COORD, (0, 0, 0), -1)
    cv2.rectangle(img, (0, 400), (639, 0), (0, 0, 0), -1)
    return img

show_video(crop)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-af2d524d653e> in <module>
#       5     return img
#       6
# ----> 7 show_video(crop)
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in show_video(func, time_limit, use_both_frames, show_video)
#     174         withRealSenseImages(display_both_frames, {'width': 640, 'height': 480, 'depth': use_both_frames}, time_limit)
#     175     else:
# --> 176         withRealSenseImages(display_frame, {'width': 640, 'height': 480, 'depth': use_both_frames}, time_limit)
#     177
#     178 def show_videox(func, time_limit = 10, use_both_frames = False, show_video = True):
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in withRealSenseImages(frameProcessor, options, limit)
#     138                                        np.asanyarray(depth_frame.get_data()))
#     139                 else:
# --> 140                     frameProcessor(np.asanyarray(frames.get_color_frame().get_data()))
#     141             elif depth:
#     142                 frameProcessor(np.asanyarray(frames.get_depth_frame().get_data()))
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in display_frame(color_image)
#     158             img = IPython.display.Image(data=f.getvalue())
#     159             display.update(img)
# --> 160             time.sleep(0.2)
#     161
#     162     def display_both_frames(color_image, depth_image):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 3: Find HSV Range of the Line
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Set the HSV lower and upper bounds to detect the line!
#     <ol style='font-size:1.75rem;line-height:1.5'>
#         <li>Use <code>hsv_select(&lt;seconds&gt;)</code> to mask for the cone!</li>
#         <li>Update <code>HSV_LOWER</code> and <code>HSV_UPPER</code>!</li>
#     </ol>
#     </p>

# %%
VIDEO_TIME = 60
hsv_select_live(VIDEO_TIME) # default: 10 sec
# Out:
# IntRangeSlider(value=(0, 179), description='Hue:', layout=Layout(width='100%'), max=179)
# IntRangeSlider(value=(0, 255), description='Saturation:', layout=Layout(width='100%'), max=255)
# IntRangeSlider(value=(0, 255), description='Value:', layout=Layout(width='100%'), max=255)

# %%
HSV_LOWER = np.array([153, 63, 56])
HSV_UPPER = np.array([179, 255, 255])

# %% [markdown]
# ## Step 4: <code>get_angle</code>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Now that we have the point we want to follow, we have to <b>determine what angle to turn the car</b> in order to get to that point.
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <code>get_angle</code> returns the turn angle of the car. We will determine whether to turn left or right, and how much to turn, depending on the location of the cone in our image. When the cone is at the center of the image, the car and cone are aligned.
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     This function is similar to the one we wrote for Cone Following, but NOT exactly.
#     <ul style='font-size:1.75rem;line-height:1.5'>
#         <li>The center of the cone is found at <code>contour_center</code></li>
#         <li>Calculate the offset error:
#             <br><code>error = contour_center - float(SCREEN_CENTER)</code></li>
#         <li>Calculate the ratio that the cone is away from the center of the screen:
#             <br><code>ratio = error / SCREEN_CENTER</code></li>
#         <li>Multiply <code>ratio</code> by the <code>max_angle</code> to find the return angle. </li>
#     </ul>
#     </p>

# %%
TURN_FACTOR = 0.10        # max turn angle (in degrees)
DRIVE_SPEED = 0.0340       # car speed

# %%
def get_angle(contour_center):
    max_angle = -abs(TURN_FACTOR) 
    
    # TASK #1: Calculate the offset error
    error = contour_center - float(SCREEN_CENTER)

    # TASK #2: Calculate the ratio
    ratio = error/SCREEN_CENTER

    # TASK #3: Calculate the turn angle
    angle = ratio*max_angle 

    # TASK #4: Return the turn angle
    return angle

# %% [markdown]
# ## Step 5: <code>get_contour_center</code>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     <code>get_contour_center</code> returns the center of the largest contour (if contours exist). Else, the function returns None.
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Run the cell block below.
#     </p>

# %%
EXIST_SIZE = 200

# %%
def get_contour_center(contours):
    greatest_contour = None
    if len(contours) > 0:
        greatest_contour = max(contours, key = cv2.contourArea) # get largest contour
        if cv2.contourArea(greatest_contour) < EXIST_SIZE:
            greatest_contour = None 
    M = None
    if greatest_contour is not None:
        M = cv2.moments(greatest_contour)
    return M

# %%
def find_contours(img):
    # TASK #1: Convert the img to from rgb to hsv.
    img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    
    # TASK #2: Mask the image using HSV_LOWER and HSV_UPPER. Save as 'mask'.
    mask = cv2.inRange(img_hsv, HSV_LOWER, HSV_UPPER)
    
    # TASK #3: Find the contours in the image. Save as 'contours'.
    contours = cv2.findContours(mask, 3, 2)[0]
    #print(contours)
    return contours, mask

# %%
def check_contours_exist(contours):
    greatest_contour = None
    
    # TASK #1: If the contours list is empty, return (False, greatest_contour)
    if contours == [] or contours is None:
        print('No contours')
        return (False, greatest_contour)
    
    greatest_contour = max(contours, key = cv2.contourArea) # get largest contour
    
    # TASK #2: If the contour area of the greatest contour is smaller than 'EXIST_SIZE', return (False, greatest_contour)
    area = cv2.contourArea(greatest_contour)
    if area < EXIST_SIZE:
        print('Too small: {}'.format(area))
        return (False, greatest_contour)
    
    return (True, greatest_contour)

# %% [markdown]
# ## Step 6: <code>line_following</code>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Now, let us write the <code>line_following</code> function below:
#     </p>

# %%
TEST_TIME = 1000

# %%
def line_follower(drive_function):
    def line_follow(color_img, depth_img):
        speed, angle = [0.0, 0.0]
   
        # run student helper functions
        contours, mask = find_contours(crop(color_img))
        contours_exist, greatest_contour = check_contours_exist(contours)
        if (contours_exist is True) and (cv2.contourArea(greatest_contour) > EXIST_SIZE):
            M = get_contour_center(contours)
            if M is not None:
                #print(M['m00'])
                if M['m00'] > EXIST_SIZE:
                    x, y = int(M['m10'] / M['m00']), int(M['m01'] / M['m00'])
                    contour_center = x
                    print(f'size: {M["m00"]} center: {contour_center}')
                    speed = DRIVE_SPEED
    #                 speed = 0.0
                    angle = get_angle(contour_center)
                    #print(angle)
                    #contour_area = cv2.contourArea(greatest_contour)
                    cv2.drawContours(color_img, [greatest_contour], -1, (0, 255, 0), 2)

#                     cv2.drawContours(color_img, contours, -1, (255, 0, 0), 2)
                    drive_function(speed, angle)
            #else:
            #    drive_function(0.0, 0.0)
            
        #return cropped image
        return color_img
   
    show_video(line_follow, TEST_TIME, True, True)

withDriving(line_follower)
# Out:
# size: 309.0 center: 412
# size: 323.0 center: 410
# size: 504.5 center: 411
# size: 583.5 center: 412
# size: 705.0 center: 413
# size: 993.0 center: 417
# size: 1796.5 center: 428
# size: 4023.0 center: 444
# size: 4424.0 center: 443
# size: 4709.0 center: 442
# size: 4230.0 center: 444
# size: 3909.0 center: 444
# size: 3848.5 center: 444
# size: 3996.0 center: 444
# size: 3966.0 center: 445
# size: 3950.0 center: 445
# size: 3980.5 center: 444
# size: 4013.0 center: 445
# size: 3961.0 center: 444
# size: 3986.5 center: 444
# size: 4012.5 center: 444
# size: 3825.0 center: 445
# size: 3982.5 center: 443
# size: 3922.5 center: 444
# size: 4070.5 center: 443
# size: 3901.0 center: 444
# size: 3871.0 center: 445
# size: 3977.0 center: 444
# size: 3984.0 center: 443
# size: 3974.5 center: 445
# size: 3952.0 center: 444
# size: 3956.0 center: 444
# size: 3834.5 center: 444
# size: 3028.5 center: 441
# size: 2843.5 center: 435
# size: 3526.5 center: 436
# size: 4211.0 center: 426
# size: 4137.5 center: 419
# size: 4638.5 center: 411
# size: 5175.5 center: 404
# size: 5436.0 center: 392
# size: 5624.0 center: 378
# size: 5589.5 center: 359
# size: 5228.5 center: 350
# size: 5804.5 center: 371
# size: 6256.0 center: 410
# size: 5041.0 center: 454
# size: 817.5 center: 485
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# Too small: 78.0
# Too small: 48.5
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# size: 1511.0 center: 474
# size: 2547.0 center: 406
# size: 2692.0 center: 437
# size: 3617.5 center: 400
# size: 3927.5 center: 400
# size: 3705.0 center: 402
# size: 5021.5 center: 406
# size: 4748.0 center: 406
# size: 4332.0 center: 407
# size: 3727.5 center: 410
# size: 4202.5 center: 415
# size: 3091.5 center: 442
# size: 5551.0 center: 437
# size: 5817.0 center: 449
# size: 3906.0 center: 459
# size: 903.0 center: 458
# No contours
# No contours
# Too small: 15.5
# size: 526.5 center: 511
# size: 858.5 center: 473
# size: 2087.0 center: 385
# size: 1647.5 center: 302
# size: 1627.0 center: 247
# size: 3617.5 center: 237
# size: 4254.0 center: 234
# size: 3643.5 center: 267
# size: 2325.0 center: 336
# size: 5700.0 center: 464
# size: 5283.5 center: 523
# size: 2457.5 center: 536
# size: 2325.5 center: 505
# size: 3184.5 center: 430
# size: 3898.5 center: 386
# size: 3980.0 center: 348
# size: 4722.5 center: 295
# size: 3592.5 center: 242
# size: 2523.5 center: 207
# size: 4177.0 center: 151
# size: 6219.0 center: 118
# size: 6804.0 center: 82
# size: 4181.5 center: 67
# size: 3240.5 center: 36
# size: 1977.5 center: 30
# No contours
# Too small: 112.0
# Too small: 28.0
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# Too small: 1.0
# No contours
# No contours
# No contours
# No contours
# Too small: 2.5
# No contours
# Too small: 1.5
# Too small: 6.0
# Too small: 7.0
# Too small: 9.0
# Too small: 2.0
# Too small: 10.0
# No contours
# No contours
# No contours
# No contours
# Too small: 6.5
# Too small: 2.0
# Too small: 8.0
# Too small: 11.0
# Too small: 5.0
# Too small: 55.0
# Too small: 53.5
# Too small: 77.0
# Too small: 75.5
# Too small: 114.0
# Too small: 78.5
# Too small: 41.5
# Too small: 39.5
# Too small: 28.5
# Too small: 41.5
# Too small: 28.0
# Too small: 44.0
# Too small: 63.5
# Too small: 31.0
# Too small: 23.0
# No contours
# Too small: 48.5
# size: 1936.5 center: 250
# size: 2322.5 center: 286
# size: 2562.5 center: 287
# size: 2770.0 center: 285
# size: 2462.5 center: 282
# size: 2486.0 center: 282
# size: 2548.5 center: 281
# size: 2663.5 center: 284
# size: 2589.5 center: 285
# size: 2564.0 center: 283
# size: 6348.5 center: 244
# Too small: 69.5
# Too small: 65.5
# Too small: 63.5
# Too small: 42.5
# Too small: 36.0
# No contours
# No contours
# No contours
# Too small: 0.0
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# Too small: 15.0
# Too small: 1.5
# size: 4935.5 center: 341
# size: 6035.5 center: 233
# size: 5776.5 center: 283
# size: 5135.0 center: 288
# size: 5630.5 center: 289
# size: 5561.0 center: 342
# size: 5459.5 center: 334
# size: 5481.0 center: 334
# size: 5474.0 center: 334
# size: 5484.5 center: 335
# size: 5399.0 center: 334
# size: 5405.5 center: 335
# size: 5327.5 center: 334
# size: 5324.5 center: 336
# size: 4589.0 center: 335
# size: 4730.0 center: 334
# size: 5241.0 center: 334
# size: 5419.5 center: 334
# size: 5461.5 center: 335
# size: 5330.0 center: 334
# size: 5367.5 center: 335
# size: 5631.0 center: 335
# size: 5564.0 center: 335
# size: 5490.0 center: 334
# size: 5496.0 center: 334
# size: 5435.5 center: 335
# size: 5176.5 center: 338
# size: 5641.5 center: 351
# size: 5239.5 center: 365
# size: 5349.5 center: 373
# size: 5388.5 center: 385
# size: 5536.5 center: 407
# size: 6022.5 center: 421
# size: 5999.5 center: 425
# size: 6215.5 center: 434
# size: 6557.5 center: 453
# size: 6528.0 center: 477
# size: 6321.5 center: 492
# size: 6280.5 center: 492
# size: 6249.5 center: 492
# size: 6235.0 center: 492
# size: 6090.0 center: 492
# size: 6265.0 center: 491
# size: 6402.0 center: 492
# size: 6464.0 center: 492
# size: 6496.0 center: 492
# size: 6521.5 center: 491
# size: 6467.5 center: 491
# size: 6453.0 center: 491
# size: 6439.0 center: 491
# size: 6370.5 center: 491
# size: 6288.0 center: 491
# size: 6267.5 center: 491
# size: 6322.0 center: 491
# size: 6355.0 center: 492
# size: 6480.0 center: 492
# size: 6413.0 center: 491
# size: 6463.0 center: 492
# size: 6447.0 center: 491
# size: 6462.0 center: 491
# size: 6423.5 center: 491
# size: 6449.0 center: 491
# size: 6444.5 center: 491
# size: 6428.0 center: 491
# size: 6381.0 center: 491
# size: 6395.0 center: 491
# size: 6506.0 center: 491
# size: 6584.0 center: 492
# size: 6582.5 center: 492
# size: 6558.0 center: 492
# size: 6398.0 center: 491
# size: 5973.5 center: 493
# size: 5788.0 center: 496
# size: 5911.0 center: 495
# size: 6240.0 center: 491
# size: 6252.0 center: 492
# size: 6272.5 center: 492
# size: 6228.0 center: 492
# size: 6329.5 center: 492
# size: 5709.0 center: 492
# size: 6259.5 center: 492
# size: 6272.5 center: 492
# size: 6266.5 center: 493
# size: 6264.0 center: 494
# size: 6257.0 center: 494
# size: 6224.5 center: 494
# size: 6215.5 center: 494
# size: 6195.0 center: 494
# size: 6274.0 center: 494
# size: 6266.5 center: 494
# size: 6272.5 center: 493
# size: 6218.5 center: 494
# size: 6290.0 center: 494
# size: 6244.0 center: 494
# size: 6267.5 center: 494
# size: 6247.0 center: 494
# size: 6286.5 center: 494
# size: 6229.0 center: 494
# size: 6251.5 center: 494
# size: 6189.0 center: 494
# size: 6252.0 center: 493
# size: 6127.0 center: 495
# size: 6250.0 center: 494
# size: 6278.5 center: 493
# size: 6230.0 center: 494
# size: 6169.0 center: 494
# size: 6256.5 center: 493
# size: 6198.5 center: 494
# size: 6235.5 center: 493
# size: 6244.0 center: 494
# size: 6079.5 center: 494
# size: 6244.0 center: 493
# size: 24784.5 center: 189
# size: 23340.0 center: 187
# size: 23190.0 center: 225
# size: 29090.0 center: 373
# size: 22334.5 center: 460
# size: 21972.0 center: 464
# size: 22778.5 center: 463
# size: 24734.5 center: 454
# size: 15813.5 center: 413
# size: 5781.5 center: 588
# size: 5777.5 center: 588
# size: 5861.0 center: 585
# size: 5801.5 center: 585
# size: 5765.5 center: 586
# size: 5821.5 center: 586
# size: 5856.5 center: 586
# size: 5851.0 center: 587
# size: 5835.5 center: 587
# size: 5825.0 center: 587
# size: 5861.0 center: 587
# size: 5824.0 center: 587
# size: 5856.5 center: 587
# size: 5906.5 center: 587
# size: 5901.0 center: 587
# size: 5892.5 center: 587
# size: 5885.5 center: 586
# size: 5941.5 center: 586
# size: 5887.0 center: 587
# size: 5845.0 center: 587
# size: 5821.5 center: 587
# size: 5783.5 center: 587
# size: 5782.5 center: 587
# size: 5645.5 center: 582
# size: 5415.0 center: 566
# size: 5322.5 center: 541
# size: 5331.5 center: 519
# size: 5618.0 center: 514
# size: 5679.0 center: 525
# size: 5678.0 center: 525
# size: 5624.5 center: 526
# size: 5706.5 center: 526
# size: 5679.0 center: 527
# size: 5645.5 center: 527
# size: 5638.0 center: 527
# size: 5707.0 center: 527
# size: 5660.0 center: 527
# size: 5672.0 center: 527
# size: 5666.5 center: 527
# size: 5725.0 center: 527
# size: 5749.5 center: 527
# size: 5753.0 center: 527
# size: 5718.5 center: 528
# size: 5729.5 center: 527
# size: 5720.0 center: 527
# size: 5798.0 center: 527
# size: 5745.5 center: 527
# size: 5710.0 center: 528
# size: 5697.5 center: 527
# size: 5724.0 center: 527
# size: 5725.5 center: 527
# size: 5718.0 center: 527
# size: 5743.5 center: 527
# size: 5747.0 center: 528
# size: 5316.0 center: 539
# size: 3285.5 center: 614
# No contours
# No contours
# Too small: 3.0
# Too small: 1.0
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# size: 507.5 center: 629
# size: 1340.5 center: 564
# size: 940.5 center: 416
# size: 430.0 center: 226
# size: 788.5 center: 95
# Too small: 3.0
# No contours
# Too small: 10.0
# Too small: 86.0
# Too small: 92.5
# Too small: 106.0
# Too small: 84.0
# Too small: 5.5
# Too small: 75.5
# Too small: 9.0
# No contours
# No contours
# Too small: 51.0
# size: 1723.5 center: 65
# size: 1931.5 center: 324
# size: 3938.5 center: 368
# size: 3932.5 center: 339
# size: 3881.0 center: 350
# size: 3706.5 center: 390
# size: 3445.5 center: 417
# size: 3399.5 center: 423
# size: 3697.5 center: 426
# size: 3376.0 center: 425
# size: 3553.0 center: 424
# size: 3490.0 center: 422
# size: 3541.0 center: 421
# size: 3484.0 center: 419
# size: 3796.0 center: 416
# size: 4159.5 center: 415
# size: 4316.0 center: 413
# size: 3972.5 center: 408
# size: 4006.0 center: 404
# size: 3911.5 center: 392
# size: 5075.0 center: 388
# size: 5177.0 center: 380
# size: 4383.0 center: 367
# size: 4871.0 center: 364
# size: 4727.5 center: 366
# size: 4031.5 center: 377
# size: 2786.0 center: 429
# size: 5560.5 center: 433
# size: 5369.5 center: 452
# size: 2329.5 center: 456
# Too small: 7.5
# No contours
# No contours
# No contours
# No contours
# size: 385.0 center: 514
# No contours
# No contours
# size: 2674.5 center: 523
# size: 3498.0 center: 529
# size: 3633.0 center: 530
# size: 3891.5 center: 530
# size: 4787.0 center: 536
# size: 3685.5 center: 530
# size: 3449.5 center: 528
# size: 3735.0 center: 531
# size: 4771.0 center: 539
# size: 4849.0 center: 545
# size: 3485.0 center: 553
# size: 3300.5 center: 556
# size: 3656.5 center: 554
# size: 3969.5 center: 551
# size: 2925.0 center: 560
# size: 730.5 center: 577
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# Too small: 140.5
# Too small: 179.5
# Too small: 176.0
# Too small: 171.5
# Too small: 151.0
# Too small: 110.5
# No contours
# No contours
# No contours
# Too small: 115.0
# No contours
# No contours
# No contours
# No contours
# Too small: 0.0
# No contours
# Too small: 63.0
# Too small: 129.0
# Too small: 122.5
# size: 264.5 center: 386
# size: 306.5 center: 384
# size: 324.0 center: 382
# size: 422.5 center: 384
# size: 580.5 center: 378
# size: 545.0 center: 374
# Too small: 172.5
# size: 696.5 center: 371
# size: 1079.0 center: 362
# size: 209.5 center: 333
# size: 810.0 center: 362
# size: 741.5 center: 354
# size: 858.0 center: 342
# size: 1375.0 center: 338
# size: 1423.5 center: 332
# size: 1492.0 center: 326
# size: 1321.5 center: 312
# size: 1390.0 center: 302
# size: 3224.0 center: 308
# size: 2858.5 center: 311
# size: 2767.0 center: 306
# size: 2622.0 center: 318
# size: 2634.0 center: 356
# size: 4284.0 center: 411
# size: 5711.5 center: 450
# size: 5110.0 center: 467
# size: 3789.0 center: 464
# size: 3657.0 center: 444
# size: 4656.5 center: 375
# size: 5464.5 center: 307
# size: 3524.0 center: 234
# size: 3993.5 center: 122
# size: 5664.0 center: 37
# size: 302.5 center: 6
# No contours
# No contours
# Too small: 0.0
# size: 428.5 center: 46
# size: 436.5 center: 52
# Too small: 32.5
# Too small: 8.0
# Too small: 2.0
# Too small: 1.0
# No contours
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# No contours
# Too small: 2.5
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.5
# Too small: 0.0
# Too small: 2.0
# Too small: 4.0
# Too small: 0.0
# Too small: 1.5
# Too small: 0.0
# Too small: 0.5
# Too small: 1.0
# Too small: 0.0
# Too small: 3.0
# Too small: 0.0
# Too small: 5.0
# Too small: 3.0
# Too small: 3.5
# Too small: 0.0
# Too small: 0.0
# Too small: 1.0
# Too small: 1.5
# Too small: 1.5
# Too small: 1.5
# Too small: 0.0
# Too small: 1.0
# Too small: 0.0
# Too small: 2.0
# Too small: 1.0
# Too small: 6.0
# Too small: 11.0
# Too small: 25.0
# Too small: 5.0
# Too small: 29.0
# Too small: 7.0
# Too small: 14.0
# Too small: 50.0
# Too small: 49.5
# Too small: 138.5
# Too small: 120.0
# Too small: 144.0
# Too small: 134.0
# Too small: 138.5
# Too small: 123.0
# Too small: 105.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.0
# Too small: 0.5
# Too small: 1.0
# No contours
# No contours
# size: 378.5 center: 159
# size: 8324.0 center: 73
# size: 7919.0 center: 56
# size: 2552.5 center: 33
# size: 2991.0 center: 34
# size: 2867.0 center: 36
# size: 21343.5 center: 146
# size: 4688.5 center: 466
# size: 4947.5 center: 465
# size: 5407.0 center: 464
# size: 4260.0 center: 465
# size: 4821.0 center: 466
# size: 6050.0 center: 470
# size: 6357.0 center: 476
# size: 5977.5 center: 494
# size: 6337.5 center: 506
# size: 6072.0 center: 522
# size: 5991.0 center: 529
# size: 6176.5 center: 545
# size: 5135.5 center: 554
# size: 5320.5 center: 551
# size: 5890.5 center: 553
# size: 5992.5 center: 552
# size: 5952.0 center: 552
# size: 6059.0 center: 555
# size: 6031.0 center: 555
# size: 6015.0 center: 558
# size: 5772.0 center: 559
# size: 5885.5 center: 568
# size: 5324.0 center: 574
# size: 5654.5 center: 577
# size: 5592.5 center: 570
# size: 6076.5 center: 555
# size: 5871.0 center: 531
# size: 5857.0 center: 504
# size: 5588.5 center: 465
# size: 5631.5 center: 419
# size: 5649.0 center: 371
# size: 5588.0 center: 324
# size: 5901.5 center: 296
# size: 5913.0 center: 282
# size: 5858.5 center: 270
# size: 5913.5 center: 260
# size: 5906.5 center: 247
# size: 5903.0 center: 238
# size: 5990.5 center: 235
# size: 6072.5 center: 236
# size: 6011.5 center: 239
# size: 6156.5 center: 244
# size: 6146.0 center: 255
# size: 6119.5 center: 276
# size: 5977.0 center: 301
# size: 5903.0 center: 324
# size: 5837.5 center: 340
# size: 5859.5 center: 353
# size: 5845.0 center: 357
# size: 5793.5 center: 359
# size: 5750.0 center: 359
# size: 5761.0 center: 352
# size: 5770.0 center: 329
# size: 5485.0 center: 283
# size: 6583.5 center: 212
# size: 6502.5 center: 148
# size: 6507.5 center: 125
# size: 5907.0 center: 135
# size: 6106.5 center: 163
# size: 6127.5 center: 196
# size: 3485.0 center: 232
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# Too small: 1.5
# Too small: 5.5
# Too small: 10.5
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# size: 7338.5 center: 345
# size: 9329.0 center: 358
# size: 6234.5 center: 410
# size: 5426.0 center: 434
# size: 5551.0 center: 435
# size: 5435.5 center: 435
# size: 5396.0 center: 435
# size: 5383.0 center: 435
# size: 5371.0 center: 435
# size: 5247.5 center: 435
# size: 5146.0 center: 434
# size: 5172.0 center: 434
# size: 5215.0 center: 435
# size: 5285.0 center: 435
# size: 5334.0 center: 435
# size: 5282.0 center: 435
# size: 5318.0 center: 435
# size: 5258.0 center: 435
# size: 5184.5 center: 434
# size: 5273.5 center: 435
# size: 5296.0 center: 435
# size: 5260.5 center: 435
# size: 5245.5 center: 435
# size: 5024.5 center: 434
# size: 5237.0 center: 435
# size: 5216.5 center: 435
# size: 5109.5 center: 434
# size: 5241.5 center: 435
# size: 4558.5 center: 431
# size: 5325.0 center: 435
# size: 5055.5 center: 436
# size: 4619.0 center: 434
# size: 5264.5 center: 434
# size: 3974.0 center: 431
# size: 4557.5 center: 431
# size: 4807.0 center: 432
# size: 4812.0 center: 432
# size: 4479.5 center: 431
# size: 4350.5 center: 433
# size: 4618.5 center: 434
# size: 4295.0 center: 434
# size: 3945.0 center: 434
# size: 4020.5 center: 435
# size: 3988.5 center: 435
# size: 4355.0 center: 436
# size: 4213.0 center: 436
# size: 4485.5 center: 437
# size: 4649.0 center: 437
# size: 4920.5 center: 436
# size: 5048.0 center: 436
# size: 4660.0 center: 437
# size: 4459.0 center: 438
# size: 4076.5 center: 436
# size: 2740.5 center: 447
# size: 3810.5 center: 436
# size: 3787.5 center: 431
# size: 3956.5 center: 428
# size: 3968.0 center: 420
# size: 4725.0 center: 412
# size: 4185.0 center: 412
# size: 4694.5 center: 408
# size: 4883.0 center: 413
# size: 5044.5 center: 424
# size: 3507.5 center: 441
# size: 5222.0 center: 465
# size: 5077.0 center: 484
# size: 2741.5 center: 483
# size: 681.0 center: 474
# No contours
# No contours
# Too small: 1.0
# Too small: 9.5
# Too small: 126.0
# Too small: 192.0
# Too small: 140.5
# size: 1235.5 center: 168
# size: 1833.0 center: 153
# size: 3596.5 center: 110
# size: 4798.0 center: 97
# size: 4703.0 center: 97
# size: 4511.0 center: 103
# size: 4435.5 center: 109
# size: 4188.0 center: 117
# size: 4369.5 center: 130
# size: 4261.5 center: 143
# size: 4278.5 center: 166
# size: 4859.5 center: 197
# size: 5585.5 center: 231
# size: 4635.0 center: 268
# size: 4052.5 center: 311
# size: 3392.0 center: 366
# size: 4156.0 center: 427
# size: 5417.5 center: 461
# size: 5844.0 center: 481
# size: 5511.5 center: 490
# size: 4515.5 center: 491
# size: 4274.0 center: 482
# size: 4922.5 center: 451
# size: 5018.5 center: 405
# size: 5180.5 center: 359
# size: 5395.0 center: 321
# size: 2985.5 center: 274
# size: 3564.0 center: 182
# size: 6663.5 center: 116
# size: 5945.5 center: 71
# size: 3904.0 center: 34
# size: 3019.5 center: 32
# Too small: 15.5
# Too small: 187.5
# Too small: 79.5
# Too small: 1.5
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# No contours
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     505     try:
# --> 506         fh = fp.fileno()
#     507         fp.flush()
#
# UnsupportedOperation: fileno
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d8a7c6ffbed2> in <module>
#      31     show_video(line_follow, TEST_TIME, True, True)
#      32
# ---> 33 withDriving(line_follower)
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in withDriving(callback)
#      67         publisher.publish(msg)
#      68
# ---> 69     callback(drive)
#      70     # Send an empty message, whch will stop the car
#      71     publisher.publish(AckermannDriveStamped())
#
# <ipython-input-13-d8a7c6ffbed2> in line_follower(drive_function)
#      29         return color_img
#      30
# ---> 31     show_video(line_follow, TEST_TIME, True, True)
#      32
#      33 withDriving(line_follower)
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in show_video(func, time_limit, use_both_frames, show_video)
#     172
#     173     if use_both_frames:
# --> 174         withRealSenseImages(display_both_frames, {'width': 640, 'height': 480, 'depth': use_both_frames}, time_limit)
#     175     else:
#     176         withRealSenseImages(display_frame, {'width': 640, 'height': 480, 'depth': use_both_frames}, time_limit)
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in withRealSenseImages(frameProcessor, options, limit)
#     136                     if color_frame and depth_frame:
#     137                         frameProcessor(np.asanyarray(color_frame.get_data()),
# --> 138                                        np.asanyarray(depth_frame.get_data()))
#     139                 else:
#     140                     frameProcessor(np.asanyarray(frames.get_color_frame().get_data()))
#
# ~/racecar_ws/jupyter_ws/online-racecar-mn-SOLUTIONS/racecar_utils.py in display_both_frames(color_image, depth_image)
#     166         if show_video:
#     167             f = BytesIO()
# --> 168             PIL.Image.fromarray(processed_img).save(f, 'jpeg')
#     169             img = IPython.display.Image(data=f.getvalue())
#     170             display.update(img)
#
# ~/.local/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2156
#    2157         try:
# -> 2158             save_handler(self, fp, filename)
#    2159         finally:
#    2160             # do what we can to clean up
#
# ~/.local/lib/python3.6/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     763     bufsize = max(ImageFile.MAXBLOCK, bufsize, len(exif) + 5, len(extra) + 1)
#     764
# --> 765     ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#     766
#     767
#
# ~/.local/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     518             else:
#     519                 while True:
# --> 520                     l, s, d = e.encode(bufsize)
#     521                     fp.write(d)
#     522                     if s:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 7: Parameter Tuning
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Tune the following parameters to improve your line follower!
#     <ul style='font-size:1.75rem;line-height:1.5'>
#         <li><code>SCREEN_CENTER</code>: to adjust for screen center offset</li>
#         <li><code>TOPLEFT_COORD</code> and <code>BOTTOMRIGHT_COORD</code>: to adjust the crop size view area</li>
#         <li><code>HSV_LOWER</code> and <code>HSV_UPPER</code>: to adjust the threshold color</li>
#         <li><code>TURN_FACTOR</code>: for the turn intensity of the car</li>
#         <li><code>DRIVE_SPEED</code>: for the speed of the car</li>
#     </ul>
#     </p>

# %% [markdown]
# # Line Following Competition!!!
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     We have prepared a race track, where we will compete against other teams to finish the course in the shortest time AND follow the line with most elegance.
#     </p>
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     Each judge will rank teams (<code>1</code> - <code>10</code>) based on: time, speed, accuracy, and elegance.
#     </p>
#
#
# <p style='font-size:1.75rem;line-height:1.5'>
#     The final score is:
#     </p>
#
# ```python
# score = judges_total_score - (time / 2)
# ```
